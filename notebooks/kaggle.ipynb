# %%
wandb_key = "put your wandb api key here please"

# %%
# !git clone https://github.com/adambarla/NMT-augment.git project
# !git -C project checkout kaggle

# %%
# !pip install -r project/requirements.txt

# %%
import wandb
wandb.login(key=wandb_key)

# %%
# %%writefile run.sh
# cd project/src/
# python3 -m training model.transformer.dim_feedforward=64 \
# model.transformer.num_encoder_layers=1 model.transformer.num_decoder_layers=1 \
# model.transformer.nhead=1 max_length=64 \
# batch_size=64

# %%
# !bash run.sh

# %%
# !rm -rf project/
